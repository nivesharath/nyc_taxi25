# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# Now you can import from src
from src.data_utils import load_and_process_taxi_data

import pandas as pd

import dagshub
dagshub.init(repo_owner="nivesharath", repo_name="nyc_taxi25", mlflow=True)
# Out:
# Accessing as nivesharath
# Initialized MLflow to track repo "nivesharath/nyc_taxi25"
# Repository nivesharath/nyc_taxi25 initialized!

# %%
rides1 = load_and_process_taxi_data(year=2022)
rides2=(load_and_process_taxi_data(year=2023))
rides = pd.concat([rides1,rides2],ignore_index=True)
# Out:
# File already exists for 2022-01.
# Loading data for 2022-01...
# Total records: 2,463,931
# Valid records: 2,415,141
# Records dropped: 48,790 (1.98%)
# Successfully processed data for 2022-01.
# File already exists for 2022-02.
# Loading data for 2022-02...
# Total records: 2,979,431
# Valid records: 2,921,118
# Records dropped: 58,313 (1.96%)
# Successfully processed data for 2022-02.
# File already exists for 2022-03.
# Loading data for 2022-03...
# Total records: 3,627,882
# Valid records: 3,551,986
# Records dropped: 75,896 (2.09%)
# Successfully processed data for 2022-03.
# File already exists for 2022-04.
# Loading data for 2022-04...
# Total records: 3,599,920
# Valid records: 3,522,113
# Records dropped: 77,807 (2.16%)
# Successfully processed data for 2022-04.
# File already exists for 2022-05.
# Loading data for 2022-05...
# Total records: 3,588,295
# Valid records: 3,509,056
# Records dropped: 79,239 (2.21%)
# Successfully processed data for 2022-05.
# File already exists for 2022-06.
# Loading data for 2022-06...
# Total records: 3,558,124
# Valid records: 3,479,411
# Records dropped: 78,713 (2.21%)
# Successfully processed data for 2022-06.
# File already exists for 2022-07.
# Loading data for 2022-07...
# Total records: 3,174,394
# Valid records: 3,096,271
# Records dropped: 78,123 (2.46%)
# Successfully processed data for 2022-07.
# File already exists for 2022-08.
# Loading data for 2022-08...
# Total records: 3,152,677
# Valid records: 3,072,196
# Records dropped: 80,481 (2.55%)
# Successfully processed data for 2022-08.
# File already exists for 2022-09.
# Loading data for 2022-09...
# Total records: 3,183,767
# Valid records: 3,106,359
# Records dropped: 77,408 (2.43%)
# Successfully processed data for 2022-09.
# File already exists for 2022-10.
# Loading data for 2022-10...
# Total records: 3,675,411
# Valid records: 3,583,466
# Records dropped: 91,945 (2.50%)
# Successfully processed data for 2022-10.
# File already exists for 2022-11.
# Loading data for 2022-11...
# Total records: 3,252,717
# Valid records: 3,165,474
# Records dropped: 87,243 (2.68%)
# Successfully processed data for 2022-11.
# File already exists for 2022-12.
# Loading data for 2022-12...
# Total records: 3,399,549
# Valid records: 3,310,530
# Records dropped: 89,019 (2.62%)
# Successfully processed data for 2022-12.
# Combining all monthly data...
# Data loading and processing complete!
# File already exists for 2023-01.
# Loading data for 2023-01...
# Total records: 3,066,766
# Valid records: 2,993,140
# Records dropped: 73,626 (2.40%)
# Successfully processed data for 2023-01.
# File already exists for 2023-02.
# Loading data for 2023-02...
# Total records: 2,913,955
# Valid records: 2,845,058
# Records dropped: 68,897 (2.36%)
# Successfully processed data for 2023-02.
# File already exists for 2023-03.
# Loading data for 2023-03...
# Total records: 3,403,766
# Valid records: 3,331,705
# Records dropped: 72,061 (2.12%)
# Successfully processed data for 2023-03.
# File already exists for 2023-04.
# Loading data for 2023-04...
# Total records: 3,288,250
# Valid records: 3,214,922
# Records dropped: 73,328 (2.23%)
# Successfully processed data for 2023-04.
# File already exists for 2023-05.
# Loading data for 2023-05...
# Total records: 3,513,649
# Valid records: 3,435,875
# Records dropped: 77,774 (2.21%)
# Successfully processed data for 2023-05.
# File already exists for 2023-06.
# Loading data for 2023-06...
# Total records: 3,307,234
# Valid records: 3,233,969
# Records dropped: 73,265 (2.22%)
# Successfully processed data for 2023-06.
# File already exists for 2023-07.
# Loading data for 2023-07...
# Total records: 2,907,108
# Valid records: 2,838,637
# Records dropped: 68,471 (2.36%)
# Successfully processed data for 2023-07.
# File already exists for 2023-08.
# Loading data for 2023-08...
# Total records: 2,824,209
# Valid records: 2,758,739
# Records dropped: 65,470 (2.32%)
# Successfully processed data for 2023-08.
# File already exists for 2023-09.
# Loading data for 2023-09...
# Total records: 2,846,722
# Valid records: 2,782,920
# Records dropped: 63,802 (2.24%)
# Successfully processed data for 2023-09.
# File already exists for 2023-10.
# Loading data for 2023-10...
# Total records: 3,522,285
# Valid records: 3,446,406
# Records dropped: 75,879 (2.15%)
# Successfully processed data for 2023-10.
# File already exists for 2023-11.
# Loading data for 2023-11...
# Total records: 3,339,715
# Valid records: 3,267,940
# Records dropped: 71,775 (2.15%)
# Successfully processed data for 2023-11.
# File already exists for 2023-12.
# Loading data for 2023-12...
# Total records: 3,376,567
# Valid records: 3,313,957
# Records dropped: 62,610 (1.85%)
# Successfully processed data for 2023-12.
# Combining all monthly data...
# Data loading and processing complete!

# %%
rides
# Out:
#              pickup_datetime  pickup_location_id
# 0        2022-01-01 00:35:40                 142
# 1        2022-01-01 00:33:43                 236
# 2        2022-01-01 00:53:21                 166
# 3        2022-01-01 00:25:21                 114
# 4        2022-01-01 00:36:48                  68
# ...                      ...                 ...
# 76196384 2023-12-31 23:04:34                 233
# 76196385 2023-12-31 23:08:15                  48
# 76196386 2023-12-31 23:16:15                 196
# 76196387 2023-12-31 23:21:58                 140
# 76196388 2023-12-31 23:10:47                 237
#
# [76196389 rows x 2 columns]

# %%
from src.data_utils import transform_raw_data_into_ts_data

ts_data = transform_raw_data_into_ts_data(rides)
ts_data.head()
# Out:
#           pickup_hour  pickup_location_id  rides
# 0 2022-01-01 00:00:00                   2      0
# 1 2022-01-01 01:00:00                   2      0
# 2 2022-01-01 02:00:00                   2      0
# 3 2022-01-01 03:00:00                   2      0
# 4 2022-01-01 04:00:00                   2      0

# %%
prop_df = ts_data[ts_data["pickup_location_id"] == 43]

# %%
prop_df.head()
# Out:
#                pickup_hour  pickup_location_id  rides
# 718320 2022-01-01 00:00:00                  43     96
# 718321 2022-01-01 01:00:00                  43     60
# 718322 2022-01-01 02:00:00                  43     22
# 718323 2022-01-01 03:00:00                  43      8
# 718324 2022-01-01 04:00:00                  43      4

# %%
import pandas as pd

# Ensure ds column is in datetime format
prop_df['pickup_hour'] = pd.to_datetime(prop_df['pickup_hour'])

# Ensure y column is numeric
prop_df['rides'] = pd.to_numeric(prop_df['rides'])

# Check data
prop_df.head()
# Out:
# C:\Users\nives\AppData\Local\Temp\ipykernel_22944\1325073704.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prop_df['pickup_hour'] = pd.to_datetime(prop_df['pickup_hour'])
# C:\Users\nives\AppData\Local\Temp\ipykernel_22944\1325073704.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prop_df['rides'] = pd.to_numeric(prop_df['rides'])
#                pickup_hour  pickup_location_id  rides
# 718320 2022-01-01 00:00:00                  43     96
# 718321 2022-01-01 01:00:00                  43     60
# 718322 2022-01-01 02:00:00                  43     22
# 718323 2022-01-01 03:00:00                  43      8
# 718324 2022-01-01 04:00:00                  43      4

# %%
prop_df = prop_df.drop(columns=["pickup_location_id"])
prop_df
# Out:
#                pickup_hour  rides
# 718320 2022-01-01 00:00:00     96
# 718321 2022-01-01 01:00:00     60
# 718322 2022-01-01 02:00:00     22
# 718323 2022-01-01 03:00:00      8
# 718324 2022-01-01 04:00:00      4
# ...                    ...    ...
# 735835 2023-12-31 19:00:00     55
# 735836 2023-12-31 20:00:00     72
# 735837 2023-12-31 21:00:00     50
# 735838 2023-12-31 22:00:00     28
# 735839 2023-12-31 23:00:00     34
#
# [17520 rows x 2 columns]

# %%
prop_df = prop_df.rename(columns={'pickup_hour': 'ds', 'rides': 'y'})

# Ensure datetime format
prop_df['ds'] = pd.to_datetime(prop_df['ds'])

# Check the updated DataFrame
prop_df.head()
# Out:
#                         ds   y
# 718320 2022-01-01 00:00:00  96
# 718321 2022-01-01 01:00:00  60
# 718322 2022-01-01 02:00:00  22
# 718323 2022-01-01 03:00:00   8
# 718324 2022-01-01 04:00:00   4

# %%
# !pip install prophet
from prophet import Prophet
p = Prophet()

p.fit(prop_df)
# Out:
# Requirement already satisfied: prophet in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from prophet) (3.10.1)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from prophet) (2.1.4)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from prophet) (0.68)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: colorama in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\nives\anaconda3\envs\nyc_taxi_proj25\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\nives\anaconda3\envs\nyc_taxi_proj25\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\nives\anaconda3\envs\nyc_taxi_proj25\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\nives\anaconda3\envs\nyc_taxi_proj25\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\nives\anaconda3\envs\nyc_taxi_proj25\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\nives\anaconda3\envs\nyc_taxi_proj25\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\nives\anaconda3\envs\nyc_taxi_proj25\Lib\site-packages)
# 04:04:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:04:47 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a dataframe for the next 12 hours
future = p.make_future_dataframe(periods=12, freq='H')

# Generate forecast
forecast = p.predict(future)

# Display the last 12 predictions
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(12))
# Out:
#                        ds        yhat  yhat_lower  yhat_upper
# 17520 2024-01-01 00:00:00   10.764733  -21.164523   42.566489
# 17521 2024-01-01 01:00:00    0.159435  -32.786150   33.424847
# 17522 2024-01-01 02:00:00   -3.994366  -37.719997   28.643977
# 17523 2024-01-01 03:00:00   -4.093118  -35.042542   28.428989
# 17524 2024-01-01 04:00:00   -2.333733  -33.927864   30.545792
# 17525 2024-01-01 05:00:00    1.961961  -29.089781   34.963478
# 17526 2024-01-01 06:00:00   11.626799  -19.283048   46.089832
# 17527 2024-01-01 07:00:00   28.267702   -7.172085   60.624585
# 17528 2024-01-01 08:00:00   49.837634   17.124404   83.311222
# 17529 2024-01-01 09:00:00   71.867959   39.730639  101.555358
# 17530 2024-01-01 10:00:00   91.258596   57.495180  123.631563
# 17531 2024-01-01 11:00:00  108.719826   75.968744  139.391460

# %%
import matplotlib.pyplot as plt

# Plot forecast
fig = p.plot(forecast)
plt.show()

# %%
p.plot_components(forecast)
plt.show()

# %%
# Merge actual vs predicted values
results = prop_df.merge(forecast[['ds', 'yhat']], on='ds', how='right')

# Plot actual vs predicted
plt.figure(figsize=(10, 5))
plt.plot(results['ds'], results['y'], label='Actual', marker='o')
plt.plot(results['ds'], results['yhat'], label='Predicted', linestyle='dashed', marker='o')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Prophet Prediction vs Actual')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Merge actual values with predicted values
results = prop_df.merge(forecast[['ds', 'yhat']], on='ds', how='inner')

mae = mean_absolute_error(results.dropna()['y'], results.dropna()['yhat'])

print(f"MAE: {mae:.2f}")
# Out:
# MAE: 18.31

# %%
import mlflow
mlflow.set_experiment("Prophet")

# Start an MLflow run
with mlflow.start_run():
        mlflow.log_metric("mean_absolute_error", mae)
# Out:
# 🏃 View run wise-steed-826 at: https://dagshub.com/nivesharath/nyc_taxi25.mlflow/#/experiments/8/runs/5dd6ca6a0d0b4733954e65aa933bb891
# 🧪 View experiment at: https://dagshub.com/nivesharath/nyc_taxi25.mlflow/#/experiments/8

# %% [markdown]
# ## Feature Training

# %%
p = Prophet(
    yearly_seasonality=False,  # Disable yearly since it's short-term
    weekly_seasonality=False,  # Disable weekly if not needed
    daily_seasonality=True
)

# Add hourly seasonality (important for 12-hour forecasts)
p.add_seasonality(name='hourly', period=24, fourier_order=12)

# Fit the model again
p.fit(prop_df)
# Out:
# 04:07:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:07:04 - cmdstanpy - INFO - Chain [1] done processing

# %%
p = Prophet(changepoint_prior_scale=0.1)  # Default is 0.05, try increasing for more flexibility
p.fit(prop_df)
# Out:
# 04:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:08:04 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = p.make_future_dataframe(periods=12, freq='H')
forecast = p.predict(future)

# %%
# Merge actual values with predicted values
results = prop_df.merge(forecast[['ds', 'yhat']], on='ds', how='inner')

mae = mean_absolute_error(results.dropna()['y'], results.dropna()['yhat'])
print(f"Updated MAE: {mae:.2f}")
# Out:
# Updated MAE: 18.32
